# %%
### Chamando base

import pandas as pd
df = pd.read_csv('dez2019gm.csv', delimiter = ';', encoding = "latin")
df
# Out:
# C:\Users\leomf\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (15,19,20,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         ATENDIMENTO_ANO ATENDIMENTO_BAIRRO_NOME  \
# 0                2009.0       CIDADE INDUSTRIAL
# 1                2009.0              FAZENDINHA
# 2                2009.0                 UBERABA
# 3                2009.0           SÍTIO CERCADO
# 4                2009.0               TATUQUARA
# ...                 ...                     ...
# 261656           2019.0              NOVO MUNDO
# 261657           2019.0               BOQUEIRÃO
# 261658           2019.0                  CAJURU
# 261659           2019.0       CIDADE INDUSTRIAL
# 261660           2019.0                  CENTRO
#
#                                   EQUIPAMENTO_URBANO_NOME  \
# 0                                                     NaN
# ...

# %%
df['LOGRADOURO_NOME'] = df['LOGRADOURO_NOME'].str.lower()
df
# Out:
#         ATENDIMENTO_ANO ATENDIMENTO_BAIRRO_NOME  \
# 0                2009.0       CIDADE INDUSTRIAL
# 1                2009.0              FAZENDINHA
# 2                2009.0                 UBERABA
# 3                2009.0           SÍTIO CERCADO
# 4                2009.0               TATUQUARA
# ...                 ...                     ...
# 261656           2019.0              NOVO MUNDO
# 261657           2019.0               BOQUEIRÃO
# 261658           2019.0                  CAJURU
# 261659           2019.0       CIDADE INDUSTRIAL
# 261660           2019.0                  CENTRO
#
#                                   EQUIPAMENTO_URBANO_NOME  \
# 0                                                     NaN
# 1                                    BOSQUE DA FAZENDINHA
# 2                                                     NaN
# 3                                                     NaN
# 4                    CENTRO DE ESPORTE E LAZER SANTA RITA
# ...

# %%
df['Endereco'] = 'rua ' +  df['LOGRADOURO_NOME'] + ', ' + df['ATENDIMENTO_BAIRRO_NOME'] + ', Curitiba' 
df
# Out:
#         ATENDIMENTO_ANO ATENDIMENTO_BAIRRO_NOME  \
# 0                2009.0       CIDADE INDUSTRIAL
# 1                2009.0              FAZENDINHA
# 2                2009.0                 UBERABA
# 3                2009.0           SÍTIO CERCADO
# 4                2009.0               TATUQUARA
# ...                 ...                     ...
# 261656           2019.0              NOVO MUNDO
# 261657           2019.0               BOQUEIRÃO
# 261658           2019.0                  CAJURU
# 261659           2019.0       CIDADE INDUSTRIAL
# 261660           2019.0                  CENTRO
#
#                                   EQUIPAMENTO_URBANO_NOME  \
# 0                                                     NaN
# 1                                    BOSQUE DA FAZENDINHA
# 2                                                     NaN
# 3                                                     NaN
# 4                    CENTRO DE ESPORTE E LAZER SANTA RITA
# ...

# %%
dfunique = pd.DataFrame()
dfunique['Endereco'] = df["Endereco"].unique()
dfunique
# Out:
#                                                 Endereco
# 0      rua davi xavier da silva, CIDADE INDUSTRIAL, C...
# 1               rua  carlos klemtz, FAZENDINHA, Curitiba
# 2      rua doutor joão de paula moura brito, UBERABA,...
# 3      rua edgard cavalcanti de albuquerque, SÍTIO CE...
# 4       rua  carlos munhoz da rocha, TATUQUARA, Curitiba
# ...                                                  ...
# 16425               rua celso aarão, TATUQUARA, Curitiba
# 16426  rua capitão argemiro monteiro wanderley, CIDAD...
# 16427                    rua iguaçu, BOQUEIRÃO, Curitiba
# 16428   rua edvald ribas borba,, SÍTIO CERCADO, Curitiba
# 16429        rua cândido hartmann,, BIGORRILHO, Curitiba
#
# [16430 rows x 1 columns]

# %%
### Número de crimes por bairro e por ano 
bairros= df[['NATUREZA1_DESCRICAO', 'ATENDIMENTO_BAIRRO_NOME', 'ATENDIMENTO_ANO',]].groupby(['ATENDIMENTO_BAIRRO_NOME', 'ATENDIMENTO_ANO']).agg('count')

# %%
bairros
# Out:
#                                          NATUREZA1_DESCRICAO
# ATENDIMENTO_BAIRRO_NOME ATENDIMENTO_ANO
# ABRANCHES               2009.0                           124
#                         2010.0                           118
#                         2011.0                            85
#                         2012.0                           127
#                         2013.0                           115
# ...                                                      ...
# ÁGUA VERDE              2016.0                           459
#                         2017.0                           476
#                         2018.0                           542
#                         2019.0                           407
# ÁGUAS BELAS             2019.0                             3
#
# [902 rows x 1 columns]

# %%
### Tipo de crimes por bairro e por ano

df["count"] = 1
crimebairro = df.groupby(['ATENDIMENTO_BAIRRO_NOME','NATUREZA1_DESCRICAO']).count()["count"].to_frame()
crimebairro
# Out:
#                                                                          count
# ATENDIMENTO_BAIRRO_NOME NATUREZA1_DESCRICAO
# ABRANCHES               AIFU                                                 3
#                         Abandono de incapaz                                  1
#                         Abordagem                                           55
#                         Achado                                               2
#                         Agressão física/verbal                              22
# ...                                                                        ...
# ÁGUA VERDE              Vias de fato                                        59
#                         Violação de Medida Protetiva Lei Maria da Penha     11
#                         Violação de sepultura/túmulo                         1
#                         Vistoria                                            25
# ...

# %%
### Tipo de crimes por bairro, por ano e por mês
df["count"] = 1
painel = df.groupby(['ATENDIMENTO_BAIRRO_NOME','ATENDIMENTO_ANO', 'OCORRENCIA_MES', 'NATUREZA1_DESCRICAO']).count()["count"].to_frame()
painel
# Out:
#                                                                             count
# ATENDIMENTO_BAIRRO_NOME ATENDIMENTO_ANO OCORRENCIA_MES NATUREZA1_DESCRICAO
# ABRANCHES               2009.0          1              Animais                  5
#                                                        Averiguação              1
#                                                        Dano                     1
#                                                        Disparo de arma          1
#                                                        Invasão                  2
# ...                                                                           ...
# ÁGUA VERDE              2019.0          11             Substância Ilícita       7
#                                                        Tentativa                1
#                                                        Trânsito                 1
# ...

# %%
### importando googlemaps para georeferenciar as ocorrências. 
## apikey leo
import googlemaps

gmaps = googlemaps.Client(key='AIzaSyCxiZ8oODe_pw7VimlHnUW7jtwE3tzUi5E')

# Geocoding an address
geocodes = gmaps.geocode('marechal floriano, curitiba')

# %%
def get_coordinates(address):
    city = '<City Name>, <Country>'
    geocode_result = gmaps.geocode(str(address) +' '+ city)
    if len(geocode_result) > 0:
        return list(geocode_result[0]['geometry']['location'].values())
    else:
        return [np.NaN, np.NaN]

# %%
d16000 = dfunique.loc[15001:16430]
d16000
# Out:
#                                                 Endereco
# 15001      rua maria brenny, CIDADE INDUSTRIAL, Curitiba
# 15002          rua são marcos, SANTA TERESINHA, Curitiba
# 15003          rua rua olindo caeteni, UBERABA, Curitiba
# 15004             rua sem endereço, NOVO MUNDO, Curitiba
# 15005         rua sem endereço, ALTO BOQUEIRÃO, Curitiba
# ...                                                  ...
# 16425               rua celso aarão, TATUQUARA, Curitiba
# 16426  rua capitão argemiro monteiro wanderley, CIDAD...
# 16427                    rua iguaçu, BOQUEIRÃO, Curitiba
# 16428   rua edvald ribas borba,, SÍTIO CERCADO, Curitiba
# 16429        rua cândido hartmann,, BIGORRILHO, Curitiba
#
# [1429 rows x 1 columns]

# %%
import numpy as np
coordinates = d16000['Endereco'].apply(lambda x: pd.Series(get_coordinates(x), index=['LATITUDE', 'LONGITUDE']))
df2 = pd.concat([d16000[:], coordinates[:]], axis="columns")

# %%
df2
# Out:
#                                                 Endereco   LATITUDE  LONGITUDE
# 15001      rua maria brenny, CIDADE INDUSTRIAL, Curitiba -25.454828 -49.350464
# 15002          rua são marcos, SANTA TERESINHA, Curitiba -28.968949 -51.071063
# 15003          rua rua olindo caeteni, UBERABA, Curitiba -25.485863 -49.219367
# 15004             rua sem endereço, NOVO MUNDO, Curitiba -25.489025 -49.294125
# 15005         rua sem endereço, ALTO BOQUEIRÃO, Curitiba -25.531764 -49.242157
# ...                                                  ...        ...        ...
# 16425               rua celso aarão, TATUQUARA, Curitiba -25.577246 -49.333216
# 16426  rua capitão argemiro monteiro wanderley, CIDAD... -25.510321 -49.302743
# 16427                    rua iguaçu, BOQUEIRÃO, Curitiba -25.447399 -49.283088
# 16428   rua edvald ribas borba,, SÍTIO CERCADO, Curitiba -25.531792 -49.263031
# 16429        rua cândido hartmann,, BIGORRILHO, Curitiba -25.426689 -49.299066
#
# [1429 rows x 3 columns]

# %%
df3 = df2.dropna()

# %%
df3.to_csv('crimegeo5.csv')

# %%
### Chamando bases

import pandas as pd
crime = pd.read_csv('crimegeo1.csv', delimiter = ',', encoding = "utf-8")
crime
# Out:
#       Unnamed: 0                                           Endereco  \
# 0              0  rua davi xavier da silva, CIDADE INDUSTRIAL, C...
# 1              1           rua  carlos klemtz, FAZENDINHA, Curitiba
# 2              2  rua doutor joão de paula moura brito, UBERABA,...
# 3              3  rua edgard cavalcanti de albuquerque, SÍTIO CE...
# 4              4   rua  carlos munhoz da rocha, TATUQUARA, Curitiba
# ...          ...                                                ...
# 3989        3995                 rua josé de lima, TINGUI, Curitiba
# 3990        3996      rua julia fech mello, SÍTIO CERCADO, Curitiba
# 3991        3997       rua papa joao xxiii, CENTRO CÍVICO, Curitiba
# 3992        3998     rua pastor antonio polito, BOQUEIRÃO, Curitiba
# 3993        3999  rua jean frederik de jaguar, SÃO MIGUEL, Curitiba
#
#        LATITUDE  LONGITUDE
# 0    -25.506167 -49.324777
# 1    -25.476345 -49.321302
# 2    -25.481361 -49.228867
# 3    -25.540397 -49.255643
# ...

# %%
### Chamando bases

import pandas as pd
crime2 = pd.read_csv('crimegeo2.csv', delimiter = ',', encoding = "utf-8")
crime2
# Out:
#       Unnamed: 0                                           Endereco  \
# 0           4000          rua carlos stellfeld, BACACHERI, Curitiba
# 1           4001             rua enetti dubard, TATUQUARA, Curitiba
# 2           4002    rua joao schleder sobrinho, BOA VISTA, Curitiba
# 3           4003              rua iretama, ALTO BOQUEIRÃO, Curitiba
# 4           4004             rua paulo nadolny, BACACHERI, Curitiba
# ...          ...                                                ...
# 3936        7946   rua waldomiro cislinski, SÍTIO CERCADO, Curitiba
# 3937        7947  rua doutor sátilas do amaral camargo, TINGUI, ...
# 3938        7948               rua leôncio derosso, XAXIM, Curitiba
# 3939        7949  rua avelina da luz da silva, SÍTIO CERCADO, Cu...
# 3940        7950           rua eponino macuco, CAPÃO RASO, Curitiba
#
#        LATITUDE  LONGITUDE
# 0    -25.432073 -49.284664
# 1    -25.567644 -49.339178
# 2    -25.391454 -49.250905
# 3    -25.550923 -49.252323
# ...

# %%
### Chamando bases

import pandas as pd
crime3 = pd.read_csv('crimegeo3.csv', delimiter = ',', encoding = "utf-8")
crime3
# Out:
#       Unnamed: 0                                           Endereco  \
# 0           7951               rua araçalina, BAIRRO ALTO, Curitiba
# 1           7952     rua martin de abreu, JARDIM BOTÂNICO, Curitiba
# 2           7953            rua elizeu santana, TATUQUARA, Curitiba
# 3           7954     rua vitorio sbalqueiro, VISTA ALEGRE, Curitiba
# 4           7955        rua andré ferreira camargo, XAXIM, Curitiba
# ...          ...                                                ...
# 3585       11547     rua r. voluntários da pátria, CENTRO, Curitiba
# 3586       11548  rua gumercindo achilles genol, PINHEIRINHO, Cu...
# 3587       11549   rua miguel pedro abib (cajuru), CAJURU, Curitiba
# 3588       11550    rua eurico fonseca dos santos, CAJURU, Curitiba
# 3589       11551  rua república islãmica do irã, JARDIM DAS AMÉR...
#
#        LATITUDE  LONGITUDE
# 0    -25.404154 -49.214302
# 1    -25.446759 -49.249023
# 2    -25.570186 -49.319158
# 3    -25.400508 -49.301526
# ...

# %%
### Chamando bases

import pandas as pd
crime4 = pd.read_csv('crimegeo4.csv', delimiter = ',', encoding = "utf-8")
crime4
# Out:
#       Unnamed: 0                                           Endereco  \
# 0          11552     rua arcésio guimarães, JARDIM SOCIAL, Curitiba
# 1          11553       rua alferes angelo sampaio, CENTRO, Curitiba
# 2          11554  rua r. hélio dirceu woitikiw, PINHEIRINHO, Cur...
# 3          11555  rua r. reverendo jahyr dittrich, SÍTIO CERCADO...
# 4          11556           rua francisco nunes, BOQUEIRÃO, Curitiba
# ...          ...                                                ...
# 3433       14996    rua johnny wendler, CIDADE INDUSTRIAL, Curitiba
# 3434       14997  rua padre eduardo stavis, SÍTIO CERCADO, Curitiba
# 3435       14998    rua daniel comboni, CIDADE INDUSTRIAL, Curitiba
# 3436       14999   rua antônio bertoldi, CAMPO DE SANTANA, Curitiba
# 3437       15000   rua vicente petrule, CIDADE INDUSTRIAL, Curitiba
#
#        LATITUDE  LONGITUDE
# 0    -25.421178 -49.232881
# 1    -25.439575 -49.285122
# 2    -25.522578 -49.292563
# 3    -25.551833 -49.269119
# ...

# %%
### Chamando bases

import pandas as pd
crime5 = pd.read_csv('crimegeo5.csv', delimiter = ',', encoding = "utf-8")
crime5
# Out:
#       Unnamed: 0                                           Endereco  \
# 0          15001      rua maria brenny, CIDADE INDUSTRIAL, Curitiba
# 1          15002          rua são marcos, SANTA TERESINHA, Curitiba
# 2          15003          rua rua olindo caeteni, UBERABA, Curitiba
# 3          15004             rua sem endereço, NOVO MUNDO, Curitiba
# 4          15005         rua sem endereço, ALTO BOQUEIRÃO, Curitiba
# ...          ...                                                ...
# 1417       16425               rua celso aarão, TATUQUARA, Curitiba
# 1418       16426  rua capitão argemiro monteiro wanderley, CIDAD...
# 1419       16427                    rua iguaçu, BOQUEIRÃO, Curitiba
# 1420       16428   rua edvald ribas borba,, SÍTIO CERCADO, Curitiba
# 1421       16429        rua cândido hartmann,, BIGORRILHO, Curitiba
#
#        LATITUDE  LONGITUDE
# 0    -25.454828 -49.350464
# 1    -28.968949 -51.071063
# 2    -25.485863 -49.219367
# 3    -25.489025 -49.294125
# ...

# %%
### concatenando 

crimezin = pd.concat([crime,crime2,crime3,crime4,crime5], ignore_index = True)
crimezin
# Out:
#        Unnamed: 0                                           Endereco  \
# 0               0  rua davi xavier da silva, CIDADE INDUSTRIAL, C...
# 1               1           rua  carlos klemtz, FAZENDINHA, Curitiba
# 2               2  rua doutor joão de paula moura brito, UBERABA,...
# 3               3  rua edgard cavalcanti de albuquerque, SÍTIO CE...
# 4               4   rua  carlos munhoz da rocha, TATUQUARA, Curitiba
# ...           ...                                                ...
# 16380       16425               rua celso aarão, TATUQUARA, Curitiba
# 16381       16426  rua capitão argemiro monteiro wanderley, CIDAD...
# 16382       16427                    rua iguaçu, BOQUEIRÃO, Curitiba
# 16383       16428   rua edvald ribas borba,, SÍTIO CERCADO, Curitiba
# 16384       16429        rua cândido hartmann,, BIGORRILHO, Curitiba
#
#         LATITUDE  LONGITUDE
# 0     -25.506167 -49.324777
# 1     -25.476345 -49.321302
# 2     -25.481361 -49.228867
# ...

# %%
base = df.merge(crimezin, left_on = 'Endereco', right_on = 'Endereco')
base
# Out:
#         ATENDIMENTO_ANO ATENDIMENTO_BAIRRO_NOME EQUIPAMENTO_URBANO_NOME  \
# 0                2009.0       CIDADE INDUSTRIAL                     NaN
# 1                2009.0       CIDADE INDUSTRIAL                     NaN
# 2                2009.0       CIDADE INDUSTRIAL                     NaN
# 3                2009.0       CIDADE INDUSTRIAL                     NaN
# 4                2009.0       CIDADE INDUSTRIAL                     NaN
# ...                 ...                     ...                     ...
# 261217           2019.0               TATUQUARA                     NaN
# 261218           2019.0       CIDADE INDUSTRIAL                     NaN
# 261219           2019.0               BOQUEIRÃO                     NaN
# 261220           2019.0           SÍTIO CERCADO                     NaN
# 261221           2019.0              BIGORRILHO                     NaN
#
#        FLAG_EQUIPAMENTO_URBANO FLAG_FLAGRANTE  \
# 0                          NÃO            NÃO
# ...

# %%
base['LATITUDE'].isnull().sum()
# Out:
# 0

# %%
base.to_csv('C:/Users/leomf/Documents/GitHub/crimecuritiba/basecrime.csv', index = False)

# %%
base.head()
# Out:
#    ATENDIMENTO_ANO ATENDIMENTO_BAIRRO_NOME EQUIPAMENTO_URBANO_NOME  \
# 0           2009.0       CIDADE INDUSTRIAL                     NaN
# 1           2009.0       CIDADE INDUSTRIAL                     NaN
# 2           2009.0       CIDADE INDUSTRIAL                     NaN
# 3           2009.0       CIDADE INDUSTRIAL                     NaN
# 4           2009.0       CIDADE INDUSTRIAL                     NaN
#
#   FLAG_EQUIPAMENTO_URBANO FLAG_FLAGRANTE       LOGRADOURO_NOME  \
# 0                     NÃO            NÃO  davi xavier da silva
# 1                     NÃO            NÃO  davi xavier da silva
# 2                     NÃO            NÃO  davi xavier da silva
# 3                     NÃO            NÃO  davi xavier da silva
# 4                     NÃO            NÃO  davi xavier da silva
#
#    NATUREZA1_DEFESA_CIVIL NATUREZA1_DESCRICAO  NATUREZA2_DEFESA_CIVIL  \
# 0                       0             Alarmes                     NaN
# ...

# %%
import folium
#creation of the clustered incident view
ctba_coordinates = (-25.5, -49.3)
map = folium.Map(location=ctba_coordinates, zoom_start=12)

# %%
from folium.plugins import MarkerCluster
mc = MarkerCluster().add_to(map)

# %%
for each in base.iterrows():
    folium.Marker([each[1]['LATITUDE'],each[1]['LONGITUDE']],
                      popup=each[1]['NATUREZA1_DESCRICAO']).add_to(mc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-5becc2149642> in <module>
# ----> 1 for each in base.iterrows():
#       2     folium.Marker([each[1]['LATITUDE'],each[1]['LONGITUDE']],
#       3                       popup=each[1]['NATUREZA1_DESCRICAO']).add_to(mc)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in iterrows(self)
#     892         klass = self._constructor_sliced
#     893         for k, v in zip(self.index, self.values):
# --> 894             s = klass(v, index=columns, name=k)
#     895             yield k, s
#     896
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     316
#     317         self.name = name
# --> 318         self._set_axis(0, index, fastpath=True)
#     319
#     320     def _init_dict(self, data, index=None, dtype=None):
#
# ...

# %%
map.save('crime1.html')

# %% [markdown]
# # Heatmap

# %%
from folium.plugins import HeatMap

# %%
heat = base[['LATITUDE','LONGITUDE','NATUREZA1_DESCRICAO']]
heat
# Out:
#          LATITUDE  LONGITUDE     NATUREZA1_DESCRICAO
# 0      -25.506167 -49.324777                 Alarmes
# 1      -25.506167 -49.324777                    Dano
# 2      -25.506167 -49.324777                 Alarmes
# 3      -25.506167 -49.324777                 Alarmes
# 4      -25.506167 -49.324777                 Alarmes
# ...           ...        ...                     ...
# 261217 -25.577246 -49.333216                   Apoio
# 261218 -25.510321 -49.302743                Trânsito
# 261219 -25.447399 -49.283088               Abordagem
# 261220 -25.531792 -49.263031      Substância Ilícita
# 261221 -25.426689 -49.299066  Perturbação do sossego
#
# [261222 rows x 3 columns]

# %%
calorzin1 = heat[heat['NATUREZA1_DESCRICAO'] == 'Roubo']
calorzin1
# Out:
#          LATITUDE  LONGITUDE NATUREZA1_DESCRICAO
# 276    -25.476345 -49.321302               Roubo
# 279    -25.476345 -49.321302               Roubo
# 285    -25.476345 -49.321302               Roubo
# 296    -25.476345 -49.321302               Roubo
# 406    -25.553679 -49.259569               Roubo
# ...           ...        ...                 ...
# 260846 -22.906847 -43.172897               Roubo
# 261014 -25.351674 -49.243053               Roubo
# 261056 -25.518375 -49.277126               Roubo
# 261087 -25.480124 -49.199344               Roubo
# 261106 -25.441031 -49.349520               Roubo
#
# [15971 rows x 3 columns]

# %%
calorzin = calorzin1[['LATITUDE','LONGITUDE']]
calorzin
# Out:
#          LATITUDE  LONGITUDE
# 276    -25.476345 -49.321302
# 279    -25.476345 -49.321302
# 285    -25.476345 -49.321302
# 296    -25.476345 -49.321302
# 406    -25.553679 -49.259569
# ...           ...        ...
# 260846 -22.906847 -43.172897
# 261014 -25.351674 -49.243053
# 261056 -25.518375 -49.277126
# 261087 -25.480124 -49.199344
# 261106 -25.441031 -49.349520
#
# [15971 rows x 2 columns]

# %%
### Adicionando um pequeno numero aleatorio em cada coluna para desagregar pontos identicos
import numpy as np
from random import random
for index, row in calorzin.iterrows():
    row["LATITUDE"] = row["LATITUDE"] + (random() - 0.5)/10000
    row["LONGITUDE"] = row["LONGITUDE"] + (random() - 0.5)/10000
calorzin
# Out:
#          LATITUDE  LONGITUDE
# 276    -25.476339 -49.321255
# 279    -25.476387 -49.321330
# 285    -25.476375 -49.321301
# 296    -25.476319 -49.321329
# 406    -25.553698 -49.259577
# ...           ...        ...
# 260846 -22.906879 -43.172930
# 261014 -25.351636 -49.243053
# 261056 -25.518393 -49.277104
# 261087 -25.480127 -49.199352
# 261106 -25.441051 -49.349482
#
# [15971 rows x 2 columns]

# %%
ctba_coordinates = (-25.5, -49.3)
mapacrime1 = folium.Map(location=ctba_coordinates, zoom_start=12)
HeatMap(calorzin, radius = 10).add_to(folium.FeatureGroup(name='Heat Map').add_to(mapacrime1))
folium.LayerControl().add_to(mapacrime1)
mapacrime1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapacrime1.save('mapacrime1.html')

# %% [markdown]
# # Coropleth

# %%
import urllib.request, json 
import requests
url = 'https://raw.githubusercontent.com/gustavokira/geo-curitiba/master/json/bairros.geo.json'
geobairros = requests.get(url).json()

# %%
geobairros

# %%
# calculating total number of incidents per district
crimedata2 = pd.DataFrame(df['ATENDIMENTO_BAIRRO_NOME'].value_counts().astype(float))
crimedata2 = crimedata2.reset_index()
crimedata2.columns = ['bairro', 'Number']
crimedata2

# %%
map1 = folium.Map(location=ctba_coordinates, zoom_start=12)
folium.GeoJson(geobairros).add_to(map1)
map1.save('teste.html')

# %%
map1 = folium.Map(location=[-25.5, -49.3], zoom_start=12)

folium.Choropleth(
    geo_data=geobairros,
    name='choropleth',
    data=crimedata2,
    columns=['bairro', 'Number'],
    key_on='features.properties.nome',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Crimes'
).add_to(map1)

folium.LayerControl().add_to(map1)

map1

# %%
map.save('map1.html')

# %%
import pandas as pd


url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
state_geo = f'{url}/us-states.json'
state_unemployment = f'{url}/US_Unemployment_Oct2012.csv'
state_data = pd.read_csv(state_unemployment)

m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'
).add_to(m)

folium.LayerControl().add_to(m)

m

# %%
state_data

# %%
geobairros1 = requests.get(state_geo).json()

# %%
geobairros1

# %%
geobairros
